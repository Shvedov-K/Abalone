# %%
import numpy as np              # Массивы (матрицы, векторы, линейная алгебра)
import matplotlib.pyplot as plt # Научная графика
# %matplotlib inline 
    # Говорим jupyter'у, чтобы весь графический вывод был в браузере, а не в отдельном окне
import pandas as pd             # Таблицы и временные ряды (dataframe, series)
import seaborn as sns           # Еще больше красивой графики для визуализации данных
import sklearn                  # Алгоритмы машинного обучения

# %% [markdown]
# # Возраст Морских Ушек

# %% [markdown]
# Таблица содержит данные о более 4 тысяч морских ушках (Abalone). Для каждой особи указаны ее пол, длина, диаметр, рост, общий вес, очищенный вес, вес внутренностей и вес скорлупы.
#
# Задача - прогнозирование возраста морского ушка(кол-ва колец Rings) на основе физических измерений.

# %%
url = "https://raw.githubusercontent.com/DKapustin/Abalone/master/abalone.csv"
data_raw = pd.read_csv(url)

# %% [markdown]
# Вначале посмотрим на размеры таблицы - количество строк (каждая строка соответствует одной особи) и количество столбцов (каждый столбец соответствует конкретному признаку):

# %%
data_raw.shape
# Out:
# (4177, 9)

# %% [markdown]
# Отображаем первые строки таблицы (по умолчанию 5):

# %%
data_raw.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Отображаем последние строки таблицы (по умолчанию 5):

# %%
data_raw.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# Столбцы (признаки) имеют имена
#
# * Sex - пол (I - Infant, F - Female, M - Male)
# * Length - длина
# * Diameter - диаметр
# * Height - высота
# * Whole weight - общий вес
# * Shucked weight - очищенный вес
# * Viscera weight - вес внутренностей
# * Shell weight - вес скорлупы
# * Rings - кол-во колец
#
# Признак  Sex - номинальный (категориальный), остальные признаки (включая целевой признак Rings) - количественный (числовой).
#
# Требуется предсказать количественный признак Rings по остальным признакам.

# %% [markdown]
# Получение имен столбцов:

# %%
data_raw.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
data_raw.index
# Out:
# RangeIndex(start=0, stop=4177, step=1)

# %%
data_raw['Sex'].dtype
# Out:
# dtype('O')

# %%
data_raw['Sex'] = data_raw['Sex'].astype('category')

# %%
data_raw['Sex'].dtype
# Out:
# CategoricalDtype(categories=['F', 'I', 'M'], ordered=False)

# %% [markdown]
# Рассмотрим зависимость кол-ва колец от длины

# %%
plt.scatter(data_raw['Rings'], data_raw['Length'])
plt.xlabel('Rings')
plt.ylabel('Length')
pass

# %%
data_raw['Rings'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005     4.0
# 0.010     4.0
# 0.050     6.0
# 0.100     6.0
# 0.500     9.0
# 0.900    14.0
# 0.950    16.0
# 0.990    20.0
# 0.995    22.0
# Name: Rings, dtype: float64

# %% [markdown]
# 99.9% всех значений признака 'Rings' находится в диапазоне от 4 до 22 (это значения квантилей, соответствующих уровням 0.005 и 0.995 соотвтетственно)

# %%
data_raw['Length'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005    0.170
# 0.010    0.195
# 0.050    0.295
# 0.100    0.355
# 0.500    0.545
# 0.900    0.660
# 0.950    0.690
# 0.990    0.735
# 0.995    0.750
# Name: Length, dtype: float64

# %% [markdown]
# 99.9% всех значений 'Length' находится в диапазоне от 0.170 до 0.750

# %%
rows_to_drop = data_raw[
    (data_raw['Rings'] < data_raw['Rings'].quantile(0.005)) | (data_raw['Rings'] > data_raw['Rings'].quantile(0.995)) | 
    (data_raw['Length']  < data_raw['Length' ].quantile(0.005)) | (data_raw['Length']  > data_raw['Length' ].quantile(0.995))].index
data = data_raw.drop(rows_to_drop)
data.shape
# Out:
# (4118, 9)

# %%
rows_to_drop
# Out:
# Int64Index([ 236,  237,  238,  239,  294,  306,  313,  314,  480,  501,  520,
#              526,  674,  678,  694,  696,  719,  720,  894, 1052, 1054, 1207,
#             1208, 1209, 1428, 1429, 1762, 1763, 1985, 1986, 1987, 2090, 2108,
#             2114, 2115, 2169, 2201, 2209, 2305, 2334, 2335, 2371, 2381, 2436,
#             2624, 2625, 2711, 3082, 3149, 3280, 3318, 3472, 3521, 3715, 3801,
#             3896, 3899, 3902, 4148],
#            dtype='int64')

# %% [markdown]
# # Визуализация

# %% [markdown]
# Сводная информация о признаках

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4118.000000  4118.000000  4118.000000   4118.000000     4118.000000
# mean      0.525200     0.408817     0.139790      0.826830        0.358942
# std       0.115975     0.096089     0.040863      0.478936        0.217204
# min       0.170000     0.105000     0.000000      0.023500        0.008000
# 25%       0.450000     0.350000     0.115000      0.446625        0.188000
# 50%       0.545000     0.425000     0.140000      0.799750        0.336000
# 75%       0.615000     0.480000     0.165000      1.149125        0.500875
# max       0.750000     0.615000     1.130000      2.825500        1.351000
#
#        Viscera weight  Shell weight        Rings
# count     4118.000000   4118.000000  4118.000000
# mean         0.180243      0.238231     9.914764
# std          0.107124      0.135941     3.065993
# min          0.000500      0.005000     4.000000
# 25%          0.094500      0.130500     8.000000
# 50%          0.171000      0.233500     9.000000
# 75%          0.252000      0.325000    11.000000
# max          0.575000      1.005000    22.000000

# %% [markdown]
# Для каждого количественного признака приведены средние значения, стандартное отклонение, минимальное и макимальное значения, медиана и значения квартилей.
#
# Информация о категориальных:

# %%
data.describe(include=['category'])
# Out:
#          Sex
# count   4118
# unique     3
# top        M
# freq    1506

# %% [markdown]
# Диаграмма рассеивания для признаков 'Rings', 'Length'

# %%
plt.scatter(data['Rings'], data['Length'], alpha=0.01)
plt.xlabel('Rings')
plt.ylabel('Length')
pass

# %%
np.random.seed(42)
random_subset = np.random.choice(np.arange(data.shape[0]), size=1000, replace=False)
plt.scatter(data.iloc[random_subset]['Rings'], data.iloc[random_subset]['Length'], alpha=0.4)
plt.xlabel('Rings')
plt.ylabel('Length')
pass

# %% [markdown]
# Диаграмма рассеивания для признаков 'Diameter', 'Length'

# %%
plt.scatter(data.iloc[random_subset]['Diameter'], data.iloc[random_subset]['Length'], alpha = .3)
plt.xlabel('Diameter')
plt.ylabel('Length')
pass

# %% [markdown]
# Из рисунка видно, что есть линейная зависимость длины от диаметра

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x='Rings', y='Length', size='Height', hue='Sex', data=data.iloc[random_subset], alpha=0.7)
pass

# %% [markdown]
# Заметно, что Infant сконцентрированы в нижнем левом углу граффика(что было предсказуемо), однако есть и выбросы, Female и Male распределены примерно одинаково

# %%
sns.pairplot(data.iloc[random_subset], hue='Sex', diag_kind='hist')
plt.legend()
pass
# Out:
# No handles with labels found to put in legend.

# %%
sns.distplot(data['Length'], bins=15)
plt.grid()
pass
# Out:
# D:\Program Files (x86)\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x='Rings', y='Length', alpha=.05, data=data)
pass

# %%
sns.distplot(data['Rings'], bins = 18)
pass
# Out:
# D:\Program Files (x86)\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Diameter'], bins = 15)
pass
# Out:
# D:\Program Files (x86)\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x="Sex", y="Length", data=data)
pass

# %%
sns.boxplot(x="Sex", y="Rings", data=data)
pass

# %%
sns.violinplot(x="Sex", y="Length", data=data)
pass

# %%
corr_mat = data.corr()
corr_mat
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.985927  0.817540      0.929677        0.902228
# Diameter        0.985927  1.000000  0.823879      0.929111        0.896362
# Height          0.817540  0.823879  1.000000      0.815836        0.771595
# Whole weight    0.929677  0.929111  0.815836      1.000000        0.969066
# Shucked weight  0.902228  0.896362  0.771595      0.969066        1.000000
# Viscera weight  0.906977  0.902781  0.795319      0.965325        0.929701
# Shell weight    0.901238  0.908659  0.812698      0.955105        0.882074
# Rings           0.549333  0.568091  0.546353      0.537052        0.419224
#
#                 Viscera weight  Shell weight     Rings
# Length                0.906977      0.901238  0.549333
# Diameter              0.902781      0.908659  0.568091
# Height                0.795319      0.812698  0.546353
# Whole weight          0.965325      0.955105  0.537052
# Shucked weight        0.929701      0.882074  0.419224
# Viscera weight        1.000000      0.907386  0.503254
# Shell weight          0.907386      1.000000  0.622302
# Rings                 0.503254      0.622302  1.000000

# %%
sns.heatmap(corr_mat, square=True, cmap='coolwarm')
pass

# %%
corr_mat > 0.85
# Out:
#                 Length  Diameter  Height  Whole weight  Shucked weight  \
# Length            True      True   False          True            True
# Diameter          True      True   False          True            True
# Height           False     False    True         False           False
# Whole weight      True      True   False          True            True
# Shucked weight    True      True   False          True            True
# Viscera weight    True      True   False          True            True
# Shell weight      True      True   False          True            True
# Rings            False     False   False         False           False
#
#                 Viscera weight  Shell weight  Rings
# Length                    True          True  False
# Diameter                  True          True  False
# Height                   False         False  False
# Whole weight              True          True  False
# Shucked weight            True          True  False
# Viscera weight            True          True  False
# Shell weight              True          True  False
# Rings                    False         False   True

# %%
corr_mat.where(np.triu(corr_mat > 0.85, k=1)).stack().sort_values(ascending=False)
# Out:
# Length          Diameter          0.985927
# Whole weight    Shucked weight    0.969066
#                 Viscera weight    0.965325
#                 Shell weight      0.955105
# Shucked weight  Viscera weight    0.929701
# Length          Whole weight      0.929677
# Diameter        Whole weight      0.929111
#                 Shell weight      0.908659
# Viscera weight  Shell weight      0.907386
# Length          Viscera weight    0.906977
# Diameter        Viscera weight    0.902781
# Length          Shucked weight    0.902228
#                 Shell weight      0.901238
# Diameter        Shucked weight    0.896362
# Shucked weight  Shell weight      0.882074
# dtype: float64

# %%
corr_mat.loc['Length', 'Whole weight'], corr_mat.loc['Length', 'Shucked weight']
# Out:
# (0.9296773840148806, 0.9022275346207965)

# %%
corr_mat.loc['Length', 'Diameter']
# Out:
# 0.9859271419457182

# %%
data.loc[(data['Sex']=='M') & (data['Length'] >= 0.6), :]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 28     M   0.605     0.475   0.180        0.9365          0.3940
# 32     M   0.665     0.525   0.165        1.3380          0.5515
# 81     M   0.620     0.510   0.175        1.6150          0.5105
# 86     M   0.625     0.465   0.140        1.1950          0.4825
# 94     M   0.695     0.560   0.190        1.4940          0.5880
# ...   ..     ...       ...     ...           ...             ...
# 4145   M   0.670     0.525   0.200        1.7405          0.6205
# 4146   M   0.695     0.530   0.210        1.5100          0.6640
# 4147   M   0.695     0.550   0.195        1.6645          0.7270
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 28            0.2190         0.295     15
# 32            0.3575         0.350     18
# 81            0.1920         0.675     12
# 86            0.2050         0.400     13
# 94            0.3425         0.485     15
# ...              ...           ...    ...
# 4145          0.2970         0.657     11
# 4146          0.4095         0.385     10
# 4147          0.3600         0.445     11
# 4174          0.2875         0.308      9
# 4176          0.3765         0.495     12
#
# [618 rows x 9 columns]

# %%
data['Sex'].unique()
# Out:
# ['M', 'F', 'I']
# Categories (3, object): ['M', 'F', 'I']

# %%
data['Sex'].value_counts()
# Out:
# M    1506
# I    1319
# F    1293
# Name: Sex, dtype: int64

# %%
sns.countplot(x='Sex', data=data)
pass

# %%
data.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# Убедились, что пропущенных занчений нет.

# %%
data['Sex'] = pd.factorize(data['Sex'])[0]

# %%
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    0   0.455     0.365   0.095        0.5140          0.2245
# 1    0   0.350     0.265   0.090        0.2255          0.0995
# 2    1   0.530     0.420   0.135        0.6770          0.2565
# 3    0   0.440     0.365   0.125        0.5160          0.2155
# 4    2   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# Нормализация

# %%
data_stand = (data - data.mean(axis = 0))/data.std(axis = 0)

# %%
data_stand.describe()
# Out:
#                 Sex        Length      Diameter        Height  Whole weight  \
# count  4.118000e+03  4.118000e+03  4.118000e+03  4.118000e+03  4.118000e+03
# mean   4.185848e-16 -1.540455e-15 -1.479395e-14  2.165868e-14 -4.515410e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.154122e+00 -3.062741e+00 -3.161825e+00 -3.420982e+00 -1.677321e+00
# 25%   -1.154122e+00 -6.484204e-01 -6.121121e-01 -6.066671e-01 -7.938525e-01
# 50%    5.490226e-02  1.707240e-01  1.684123e-01  5.140491e-03 -5.654126e-02
# 75%    1.263926e+00  7.743041e-01  7.407970e-01  6.169480e-01  6.729402e-01
# max    1.263926e+00  1.938351e+00  2.145741e+00  2.423272e+01  4.173146e+00
#
#        Shucked weight  Viscera weight  Shell weight         Rings
# count    4.118000e+03    4.118000e+03  4.118000e+03  4.118000e+03
# mean     3.936196e-15   -3.887560e-15  5.702093e-16  6.163113e-17
# std      1.000000e+00    1.000000e+00  1.000000e+00  1.000000e+00
# min     -1.615722e+00   -1.677895e+00 -1.715673e+00 -1.929151e+00
# 25%     -7.870097e-01   -8.004078e-01 -7.924799e-01 -6.245170e-01
# 50%     -1.056238e-01   -8.628271e-02 -3.479955e-02 -2.983583e-01
# 75%      6.534538e-01    6.698497e-01  6.382854e-01  3.539589e-01
# max      4.567394e+00    3.685044e+00  5.640447e+00  3.941704e+00

# %% [markdown]
# # Классификация

# %%
X = data.drop('Rings', axis = 1) # выбрасываем столбец 'Rings'
y = data['Rings']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
X = X.to_numpy()

# %% [markdown]
# y = np.array(y != 12, dtype='int')

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4118, dtype: int64

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (4118, 8)
# (4118,)

# %% [markdown]
# Разобьем данные на обучающую и тестовую выборку

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 2882 1236

# %% [markdown]
# Метод К ближайших соседей (с числом соседей: 2,3,5,7,10,15,20,50,100,1000)

# %%
from sklearn.neighbors import KNeighborsClassifier
neighbors_array = np.array([2,3,5,7,10,15,20,50,100,1000])
for i in range (10):
    knn = KNeighborsClassifier(n_neighbors = neighbors_array[i])
    knn.fit(X_train, y_train)
    y_test_predict = knn.predict(X_test)
    err_test  = np.mean(y_test  != y_test_predict)
    y_train_predict = knn.predict(X_train)
    err_train  = np.mean(y_train  != y_train_predict)
    print('neighbours =',neighbors_array[i],'err_train =',err_train,'err_test =', err_test)
    i=i+1
# Out:
# neighbours = 2 err_train = 0.4104788341429563 err_test = 0.7783171521035599
# neighbours = 3 err_train = 0.48820263705759886 err_test = 0.7807443365695793
# neighbours = 5 err_train = 0.5475364330326162 err_test = 0.767799352750809
# neighbours = 7 err_train = 0.5763358778625954 err_test = 0.7621359223300971
# neighbours = 10 err_train = 0.6186675919500347 err_test = 0.7645631067961165
# neighbours = 15 err_train = 0.6394864677307426 err_test = 0.738673139158576
# neighbours = 20 err_train = 0.655794587092297 err_test = 0.7483818770226537
# neighbours = 50 err_train = 0.6894517696044413 err_test = 0.7451456310679612
# neighbours = 100 err_train = 0.7113115891741846 err_test = 0.7411003236245954
# neighbours = 1000 err_train = 0.7765440666204025 err_test = 0.8098705501618123

# %% [markdown]
# С увеличением числа соседей ошибка на тренировочной выборке (err_train) увеличивается, а на тестовой (err_test) уменьшается.
#
# Начиная с 15 соседей, показатели не изменются

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 2882 1236

# %%
from sklearn.neural_network import MLPClassifier
mlp_model_lbfgs = MLPClassifier(hidden_layer_sizes = (100,),
                          solver = 'lbfgs', 
                          activation = 'logistic',
                          random_state = 7,
                          max_iter = 10000)
mlp_model_adam = MLPClassifier(hidden_layer_sizes = (50,),
                          solver = 'adam', 
                          activation = 'logistic',
                          random_state = 7,
                          max_iter = 10000)
mlp_model_sgd = MLPClassifier(hidden_layer_sizes = (50,),
                          solver = 'sgd', 
                          activation = 'logistic',
                          random_state = 7,
                          max_iter = 10000)

# %%
# %%time
mlp_model_lbfgs.fit(X_train, y_train)
mlp_model_adam.fit(X_train, y_train)
mlp_model_sgd.fit(X_train, y_train)
# Out:
# D:\Program Files (x86)\Anaconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Wall time: 2min 31s
# MLPClassifier(activation='logistic', hidden_layer_sizes=(50,), max_iter=10000,
#               random_state=7, solver='sgd')

# %%
y_train_pred_lbfgs = mlp_model_lbfgs.predict(X_train)
y_test_pred_lbfgs = mlp_model_lbfgs.predict(X_test)
y_train_pred_adam = mlp_model_adam.predict(X_train)
y_test_pred_adam = mlp_model_adam.predict(X_test)
y_train_pred_sgd = mlp_model_sgd.predict(X_train)
y_test_pred_sgd = mlp_model_sgd.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.5999306037473976 0.7516181229773463

# %%
from sklearn.metrics import accuracy_score
# Out:
# 0.5284524635669674

# %% [markdown]
# quasi-Newton methods

# %%
accuracy_score(y_train, y_train_pred_lbfgs)
# Out:
# 0.5284524635669674

# %%
accuracy_score(y_test, y_test_pred_lbfgs)
# Out:
# 0.23220064724919093

# %% [markdown]
# stochastic gradient descent

# %%
accuracy_score(y_train, y_train_pred_adam)
# Out:
# 0.28487161693268565

# %%
accuracy_score(y_test, y_test_pred_adam)
# Out:
# 0.2669902912621359

# %% [markdown]
# stochastic gradient-based optimizer proposed by Kingma, Diederik, and Jimmy Ba

# %%
accuracy_score(y_train, y_train_pred_sgd)
# Out:
# 0.2498265093684941

# %%
accuracy_score(y_test, y_test_pred_sgd)
# Out:
# 0.22249190938511326
